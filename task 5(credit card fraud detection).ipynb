# %%
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df1 = pd.read_csv("creditcard.csv")
df1.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df1.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
round(df1.describe(), 3).T
# Out:
#            count       mean        std      min        25%        50%  \
# Time    284807.0  94813.860  47488.146    0.000  54201.500  84692.000
# V1      284807.0      0.000      1.959  -56.408     -0.920      0.018
# V2      284807.0      0.000      1.651  -72.716     -0.599      0.065
# V3      284807.0     -0.000      1.516  -48.326     -0.890      0.180
# V4      284807.0      0.000      1.416   -5.683     -0.849     -0.020
# V5      284807.0      0.000      1.380 -113.743     -0.692     -0.054
# V6      284807.0      0.000      1.332  -26.161     -0.768     -0.274
# V7      284807.0     -0.000      1.237  -43.557     -0.554      0.040
# V8      284807.0      0.000      1.194  -73.217     -0.209      0.022
# V9      284807.0     -0.000      1.099  -13.434     -0.643     -0.051
# V10     284807.0      0.000      1.089  -24.588     -0.535     -0.093
# V11     284807.0      0.000      1.021   -4.797     -0.762     -0.033
# ...

# %%
df1.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 1081

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df2 = df1.drop_duplicates()

# %%
df2
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df2["Class"].value_counts()
# Out:
# 0    283253
# 1       473
# Name: Class, dtype: int64

# %%
sns.countplot(x='Class', data=df2)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
realdf = df2[df2["Class"] == 0]
realdf
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
frauddf= df2[df2["Class"] == 1]
frauddf
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
sample_realdf= realdf.sample(n = 473)
sample_realdf
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 25896    33814.0  1.172657  0.314082  0.661065  2.586321 -0.201487  0.076632
# 1860      1438.0 -1.768929  1.208230  1.832726 -0.922455  0.213062 -0.803723
# 95986    65553.0 -0.282576  0.438602 -0.151709 -0.584800  3.015630  3.252211
# 112332   72615.0 -1.717542  1.599831 -0.520617 -1.699833 -1.192149 -1.885774
# 57774    48068.0  1.212023  0.319965  0.330194  0.575035 -0.289755 -0.740232
# ...          ...       ...       ...       ...       ...       ...       ...
# 28836    35187.0  1.036585 -0.276627  1.185863  1.746153 -0.786663  0.592725
# 264343  161381.0 -0.053275 -0.526493 -0.094999 -1.903727  1.043864 -1.017815
# 281481  170207.0 -0.791071  1.088291  0.757715 -0.968113  0.102315 -0.229971
# 66897    52268.0  1.186594  0.585160  0.103621  2.383549  0.118333 -0.553260
# 132603   80047.0  1.359233 -1.312460  0.752920 -1.081128 -1.853751 -0.614727
#
# ...

# %%
training_df = pd.concat([sample_realdf, frauddf], axis = 0)
training_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 25896    33814.0  1.172657  0.314082  0.661065  2.586321 -0.201487  0.076632
# 1860      1438.0 -1.768929  1.208230  1.832726 -0.922455  0.213062 -0.803723
# 95986    65553.0 -0.282576  0.438602 -0.151709 -0.584800  3.015630  3.252211
# 112332   72615.0 -1.717542  1.599831 -0.520617 -1.699833 -1.192149 -1.885774
# 57774    48068.0  1.212023  0.319965  0.330194  0.575035 -0.289755 -0.740232
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
training_df["Class"].value_counts()
# Out:
# 0    473
# 1    473
# Name: Class, dtype: int64

# %%
X = training_df.drop(columns = "Class", axis = 1)
y = training_df['Class']

# %%
X
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 25896    33814.0  1.172657  0.314082  0.661065  2.586321 -0.201487  0.076632
# 1860      1438.0 -1.768929  1.208230  1.832726 -0.922455  0.213062 -0.803723
# 95986    65553.0 -0.282576  0.438602 -0.151709 -0.584800  3.015630  3.252211
# 112332   72615.0 -1.717542  1.599831 -0.520617 -1.699833 -1.192149 -1.885774
# 57774    48068.0  1.212023  0.319965  0.330194  0.575035 -0.289755 -0.740232
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y
# Out:
# 25896     0
# 1860      0
# 95986     0
# 112332    0
# 57774     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 946, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
X_train.shape
# Out:
# (709, 30)

# %%
X_test.shape
# Out:
# (237, 30)

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
preds_train = model.predict(X_train)
print("Model accuracy: ", accuracy_score(preds_train, y_train))
# Out:
# Model accuracy:  0.9393511988716502

# %%
preds_test = model.predict(X_test)
print("Model Accuracy:", accuracy_score(preds_test, y_test))
# Out:
# Model Accuracy: 0.9367088607594937

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ax = ConfusionMatrixDisplay.from_predictions(y_test, preds_test)

plt.show()
